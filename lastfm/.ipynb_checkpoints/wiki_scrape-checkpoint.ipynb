# %%
from bs4 import BeautifulSoup
import urllib2
wiki = "http://en.wikipedia.org/wiki/List_of_postcode_districts_in_the_United_Kingdom"
header = {'User-Agent': 'Mozilla/5.0'} #Needed to prevent 403 error on Wikipedia
req = urllib2.Request(wiki,headers=header)
page = urllib2.urlopen(req)
soup = BeautifulSoup(page)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-bd92d7822e82> in <module>()
#       1 from bs4 import BeautifulSoup
# ----> 2 import urllib2
#       3 wiki = "http://en.wikipedia.org/wiki/List_of_postcode_districts_in_the_United_Kingdom"
#       4 header = {'User-Agent': 'Mozilla/5.0'} #Needed to prevent 403 error on Wikipedia
#       5 req = urllib2.Request(wiki,headers=header)
#
# ImportError: No module named 'urllib2'

# %%
import requests

page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>A simple example page</title>
#  </head>
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
list(html.children)
# Out:
# ['\n', <head>
#  <title>A simple example page</title>
#  </head>, '\n', <body>
#  <p>Here is some simple content for this page.</p>
#  </body>, '\n']

# %%
body = list(html.children)[3]
list(body.children)
# Out:
# ['\n', <p>Here is some simple content for this page.</p>, '\n']

# %%
p = list(body.children)[1]
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %%
page = requests.get("https://en.wikipedia.org/wiki/YG_(rapper)")
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    YG (rapper) - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
html = list(soup.children)[2]

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <meta charset="utf-8"/>
#  <title>YG (rapper) - Wikipedia</title>
#  <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
bio = (soup.select("html body")[0]).find_all('p')[0].get_text()
bio
# Out:
# 'Keenon Daequan Ray Jackson (born March 9, 1990),[1] known professionally as YG, is an American rapper from Compton, California. In 2009, he released his debut single, "Toot It and Boot It" featuring Ty Dolla Sign, which peaked at number 67 on the Billboard Hot 100.[2] The single\'s success resulted in him signing to Def Jam Recordings.[3] In the following years, YG released mixtapes such as The Real 4Fingaz and Just Re\'d Up 2, among others.'

# %%
for i in bio.split(' '):
    if i == 'from':
        x = [i for i,x in enumerate(bio.split(' ')) if x == 'from']
        location = bio.split(' ')[x[0]+1] + bio.split(' ')[x[0]+2] 
        print(location.split(' '))
        #print(x[0]+1)
# Out:
# LongBeach,

# %%
page = requests.get("https://en.wikipedia.org/wiki/Snoop_Dogg")
soup = BeautifulSoup(page.content, 'html.parser')
bio = (soup.select("html body")[0]).find_all('p')[0].get_text()
for i in bio.split(' '):
    if i == 'from':
        x = [i for i,x in enumerate(bio.split(' ')) if x == 'from']
        location = bio.split(' ')[x[0]+1] + bio.split(' ')[x[0]+2] 
        print(location.split(' '))
print(bio.split(' '))
# Out:
# ['LongBeach,']
# ['Cordozar', 'Calvin', 'Broadus,', 'Jr.', '(born', 'October', '20,', '1971),[1][2]', 'known', 'professionally', 'as', 'Snoop', 'Dogg', '(sometimes', 'shortened', 'to', 'Snoop', 'and', 'formerly', 'called', 'Snoop', 'Doggy', 'Dogg', 'and', 'Snoop', 'Lion),', 'is', 'an', 'American', 'rapper', 'and', 'actor', 'from', 'Long', 'Beach,', 'California.', 'His', 'music', 'career', 'began', 'in', '1992', 'when', 'he', 'was', 'discovered', 'by', 'Dr.', 'Dre', 'of', 'N.W.A,', 'and', 'as', 'a', 'result', 'was', 'prominently', 'featured', 'throughout', 'Dr.', "Dre's", 'solo', 'debut', 'album,', 'The', 'Chronic', '(1992).', 'He', 'has', 'since', 'sold', 'over', 'twenty-three', 'million', 'albums', 'in', 'the', 'United', 'States', 'and', 'thirty-five', 'million', 'albums', 'worldwide.[3][4][5]']

# %%
import pandas as pd
#open artistlist textfile
data = pd.read_csv('C:/Users/danil/Documents/GitHub/related_music/lastfm/names.csv', encoding = 'latin-1')
col = data.columns.tolist()
col = ['artist',
 'tag3',
 'tag2',
 'tag1',
 'similar1',
 'similar2',
 'similar3',
 'playcount',
 'listener_count']
data = data[col]
data = data.dropna()
data.head()
# Out:
#       artist         tag3                 tag2     tag1           similar1  \
# 2   12 Gauge       hiphop                 bass  Hip-Hop              Duice
# 3   2 Chainz  Dirty South                  rap  Hip-Hop         Gucci Mane
# 4  2 Pistols          rnb                  rap  Hip-Hop          Yung Berg
# 6  21 Savage      hip hop              Hip-Hop     trap        Kodak Black
# 7       2Mex          rap  underground hip-hop  Hip-Hop  Mystik Journeymen
#
#              similar2          similar3  playcount  listener_count
# 2            504 Boyz  Sway & King Tech     9842.0          2659.0
# 3              Future    French Montana  6419267.0        519208.0
# 4              Brisco     Playaz Circle   616984.0        165783.0
# 6        LIL UZI VERT        Famous Dex   793562.0         50343.0
# 7  Of Mexican Descent           Bicasso   152597.0         14838.0

# %%
def get_info(artist_name):
    wiki_url ="https://en.wikipedia.org/wiki/"
    isascii = lambda s: len(s) == len(s.encode())
    if isascii(artist_name) == True:
        #put underscores between artist string
        art_split = artist_name.split(' ')
        art_name_fin = '_'.join(art_split)
        return wiki_url[:30] + art_name_fin + wiki_url[30:]
    else:
        return False

# %%
import numpy as np
def get_location(df):
    for i in df:
        page1 = requests.get(get_info(i))
        soup1 = BeautifulSoup(page1.content, 'html.parser')
        bio1 = (soup1.select("html body")[0]).find_all('p')[0].get_text()
        split = bio1.split(' ')
        x = [i for i,x in enumerate(bio.split(' ')) if x == 'from']
        if len(x) == 1:
            location = bio.split(' ')[x[0]+1] +' ' + bio.split(' ')[x[0]+2] +' '+ bio.split(' ')[x[0]+3]
            location = ''.join(location)
            return body
#         else:
#             location = np.nan
#             return location

# %%
for i in range(10):
    print(get_location(data['artist'].iloc[i]))
# Out:
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %%
for i in range(10):
    print(get_info(data['artist'].iloc[i]))
# Out:
# https://en.wikipedia.org/wiki/12_Gauge
# https://en.wikipedia.org/wiki/2_Chainz
# https://en.wikipedia.org/wiki/2_Pistols
# https://en.wikipedia.org/wiki/21_Savage
# https://en.wikipedia.org/wiki/2Mex
# https://en.wikipedia.org/wiki/360
# https://en.wikipedia.org/wiki/40_Glocc
# https://en.wikipedia.org/wiki/50_Cent
# https://en.wikipedia.org/wiki/6_Tre_G
# https://en.wikipedia.org/wiki/9th_Wonder

# %%
data['location'] = data['artist'].apply(get_location)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383             try:  # Python 2.7, use buffering of HTTP responses
# --> 384                 httplib_response = conn.getresponse(buffering=True)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-212-7ef6fecdb7e5> in <module>()
# ----> 1 data['location'] = data['artist'].apply(get_location)
#
# ...
