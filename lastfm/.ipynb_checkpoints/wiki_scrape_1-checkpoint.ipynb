# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
#open artistlist textfile
data = pd.read_csv('C:/Users/danil/Documents/GitHub/related_music/lastfm/names.csv', encoding = 'latin-1')
col = data.columns.tolist()
col = ['artist',
 'tag3',
 'tag2',
 'tag1',
 'similar1',
 'similar2',
 'similar3',
 'playcount',
 'listener_count']
data = data[col]
data = data.dropna()
data.head()

def get_info(artist_name):
    wiki_url ="https://en.wikipedia.org/wiki/"
    isascii = lambda s: len(s) == len(s.encode())
    if isascii(artist_name) == True:
        #put underscores between artist string
        art_split = artist_name.split(' ')
        art_name_fin = '_'.join(art_split)
        return wiki_url[:30] + art_name_fin + wiki_url[30:]
    else:
        return False
#add sleeper with time module
import numpy as np
def get_location(df):
    page1 = requests.get(get_info(df))
    soup1 = BeautifulSoup(page1.content, 'html.parser')
    bio1 = (soup1.select("html body")[0]).find_all('p')[0].get_text()
    split = bio1.split(' ')
    x = [i for i,x in enumerate(split) if x == 'from']
    try:
        #len(x) == 1 & soup1.status_code == 200
        location = split[x[0]+1] +' ' + split[x[0]+2] +' '+ split[x[0]+3]
        location = ''.join(location)
        return location 
    except:
        pass

# %%
#makes list
loc_list = []
for i in range(len(data['artist'])):
    time.sleep(2)
    loc_list.append(get_location(data['artist'].iloc[i]))

# %%
len(loc_list)
# Out:
# 1038

# %%
loc_list
# Out:
# [None,
#  'College Park, Georgia.',
#  'Tarpon Springs, Florida.[2]',
#  'Atlanta, Georgia. He',
#  'Los Angeles, California.[1]',
#  None,
#  None,
#  None,
#  'Fayette, Alabama. He',
#  'Midway, North Carolina,',
#  None,
#  None,
#  None,
#  'Carson, California. In',
#  'Los Angeles, California.',
#  'his debut studio',
#  'Los Angeles, California,',
#  None,
#  None,
#  'the South Bronx,',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '2006 census figures,',
#  None,
#  'his debut album',
#  None,
#  'Queens, New York',
#  None,
#  None,
#  None,
#  None,
#  'Akron, Ohio. His',
#  'Oxnard, California. He',
#  'San Francisco, California.',
#  'New York City.',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Detroit, Michigan, whose',
#  'the Southwestern United',
#  None,
#  "New York City's",
#  'Harlem, New York.',
#  'the Bronx neighborhood',
#  None,
#  None,
#  None,
#  'the Forest Hills,',
#  None,
#  None,
#  'a variation on',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'New Orleans. His',
#  None,
#  None,
#  None,
#  'the Guadalimar to',
#  None,
#  None,
#  None,
#  None,
#  'Philadelphia, Pennsylvania. As',
#  'the Block" (2013),',
#  None,
#  None,
#  None,
#  None,
#  'Atlanta, Georgia. He',
#  'Houston, Texas and',
#  'Meridian, Mississippi. He',
#  'Atlanta, Georgia. He',
#  None,
#  None,
#  'Houston, Texas. He',
#  None,
#  'Houston, Texas. He',
#  None,
#  'Houston, Texas and',
#  None,
#  'Kansas City, Missouri,',
#  None,
#  'Detroit, Michigan. Sean',
#  'Boston, Massachusetts, and',
#  None,
#  None,
#  None,
#  'Nanuet, New York',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Detroit, Michigan. Icewood',
#  'Queensbridge, New York,',
#  'Mt. Clemens, Michigan.',
#  'Panama City, Florida.',
#  None,
#  'writing and producing',
#  'Atlanta, Georgia who',
#  'Brooklyn, New York.',
#  None,
#  None,
#  'Detroit, Michigan.[2] His',
#  None,
#  None,
#  'Covington, Georgia. Hutto',
#  'Baton Rouge, Louisiana.[1]',
#  None,
#  None,
#  None,
#  'Miami-Dade County, Florida.',
#  None,
#  'Sacramento, California.[3] Since',
#  None,
#  None,
#  None,
#  None,
#  'The Bronx borough',
#  'Long Island, New',
#  None,
#  'Los Angeles, California.[1]',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Bronx borough',
#  None,
#  'Harlem, New York.',
#  None,
#  'Brooklyn, New York.',
#  None,
#  None,
#  'Los Angeles, California.',
#  'Columbus, Georgia, and',
#  None,
#  None,
#  None,
#  None,
#  'San Francisco.[3] He',
#  'Vallejo, California. He',
#  'Get Busy Committee,',
#  None,
#  None,
#  'Houston, Texas.[2] He',
#  'the West Chatham',
#  None,
#  None,
#  'Milpitas, California, United',
#  None,
#  "Geena Davis's character",
#  'Pittsburgh, Pennsylvania. Throughout',
#  'The Bronx, New',
#  'artists such as',
#  'Chicago, Illinois. During',
#  None,
#  'Jersey City, New',
#  None,
#  None,
#  'Queens, New York.',
#  None,
#  'information such as',
#  None,
#  'a young age.',
#  'Norwalk, Connecticut. Chris',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Oakland, California. He',
#  None,
#  None,
#  'the 1970s, especially',
#  None,
#  None,
#  None,
#  'Nas on his',
#  'The Bronx, New',
#  None,
#  'Oakland, California. Their',
#  None,
#  'the criminal endeavors',
#  None,
#  'Long Beach, California.',
#  'Stone Mountain, Georgia.[2]',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Dallas. In addition',
#  'Joliet, Illinois. Beginning',
#  None,
#  None,
#  'Washington, DC. In',
#  None,
#  None,
#  None,
#  'Detroit, Michigan. He',
#  None,
#  'East Harlem, New',
#  None,
#  None,
#  None,
#  None,
#  'Long Beach, California.',
#  None,
#  None,
#  'Detroit, Michigan. She',
#  'Philadelphia, Pennsylvania and',
#  'Charlotte, North Carolina.[5]',
#  'Carol City, Florida.[2]',
#  'Pro to Derek',
#  None,
#  None,
#  None,
#  None,
#  'Houston, Texas. He',
#  None,
#  'Tampa, Florida, founded',
#  'diamond to graphite',
#  'the Bronx, New',
#  None,
#  'Brooklyn, New York.',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Detroit, Michigan.[1] He',
#  None,
#  'Philadelphia, Pennsylvania. He',
#  None,
#  None,
#  'Rochester, New York.',
#  "Detroit, Michigan. He's",
#  None,
#  'New York City.',
#  None,
#  'nature and extensive',
#  'Los Angeles, California.',
#  'Memphis, Tennessee.[1] He',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Montgomery, Alabama. He',
#  None,
#  None,
#  'Leimert Park, Los',
#  None,
#  None,
#  'Los Angeles, California.',
#  None,
#  None,
#  None,
#  None,
#  'Houston, Texas. Active',
#  None,
#  'the Bronx borough',
#  None,
#  None,
#  None,
#  'San Jose, California.[1]',
#  None,
#  "Vallejo, California. He's",
#  'Oakland, California.[1] He',
#  None,
#  'the Koreatown neighborhood',
#  'Obio-Akpor, Rivers State.[2]',
#  None,
#  'Vallejo, California. He',
#  'Houston, Texas.[1] He',
#  'Los Angeles, California.',
#  None,
#  None,
#  'Boston, Massachusetts, United',
#  'Newark, New Jersey.',
#  'El Producto), is',
#  'bronchopneumonia, and his',
#  'Detroit, Michigan. He',
#  None,
#  None,
#  None,
#  'Detroit, Michigan known',
#  'orthodox Judeo-Christian religion',
#  None,
#  None,
#  'Saint Paul, Minnesota.[2]',
#  'one of the',
#  'Brooklyn, New York',
#  None,
#  None,
#  'Fresno, California.[1] He',
#  None,
#  None,
#  'Washington, D.C.. He',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Carol City, Florida.[4]',
#  'Los Angeles, California.',
#  'New York City,',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'the project titled',
#  'Atlanta, Georgia. He',
#  'Long Island, New',
#  None,
#  'Chicago, Illinois. He',
#  'South Jamaica, Queens,',
#  "Kurupt's Tha Streetz",
#  None,
#  None,
#  None,
#  None,
#  'Miami, Florida. They',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Oakland, California.[1] His',
#  'Harlem, New York',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Los Angeles, California.',
#  None,
#  None,
#  None,
#  None,
#  'New Rochelle, New',
#  None,
#  'Compton, California. He',
#  None,
#  'Atlanta, Georgia. In',
#  'New Orleans. He',
#  'Compton, California.[1] Born',
#  'Detroit, Michigan. He',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Baltimore, Maryland, better',
#  None,
#  'Cincinnati, Ohio. He',
#  'Fontana, California. In',
#  None,
#  'Los Angeles, California.',
#  None,
#  'the University of',
#  'Los Angeles, California.',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'her first full-length',
#  'Brooklyn, New York.',
#  'Bloomfield, New Jersey.',
#  'Atlanta, Georgia, who',
#  None,
#  None,
#  'Memphis, Tennessee. First',
#  None,
#  'Chattanooga, Tennessee. Rashad',
#  None,
#  None,
#  None,
#  'critics, and the',
#  None,
#  'The Bronx, New',
#  'the mid-1990s underground',
#  None,
#  'St. Louis best',
#  None,
#  None,
#  'the Cypress Village',
#  None,
#  'Harlem, New York.',
#  'Queens, New York.',
#  'Cape Town, South',
#  'Pittsburg, California. The',
#  None,
#  None,
#  'Harlem, New York,[1]',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Decatur, Georgia. In',
#  None,
#  'New Orleans. Electronica',
#  None,
#  'Watts, California. Rock',
#  'southeast San Diego,',
#  'his debut album',
#  'Atlanta, Georgia. He',
#  None,
#  'the neighborhood of',
#  'Chicago, Illinois.[1] In',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'the Fillmore neighborhood',
#  'the Harlem neighborhood',
#  'Memphis, Tennessee. He',
#  None,
#  None,
#  'his 1980 self-titled',
#  None,
#  'Atlanta, Georgia. He',
#  None,
#  None,
#  None,
#  'Central Islip, New',
#  'the Funktown section',
#  None,
#  None,
#  None,
#  'Miami, Florida. Dahlia,',
#  None,
#  None,
#  'Oakland, California; He',
#  None,
#  None,
#  None,
#  'Baton Rouge, Louisiana.[3][4][5]',
#  None,
#  None,
#  'Memphis, Tennessee. He',
#  None,
#  'Cleveland, Ohio. Cudi',
#  'Los Angeles, California.',
#  'Los Angeles, California.',
#  None,
#  None,
#  'New Orleans, Louisiana.',
#  None,
#  "OutKast's 2000 LP",
#  'Atlanta, Georgia.[1] Kilo',
#  'Cleveland, Ohio. He',
#  'Detroit, Michigan. He',
#  'Compton, California. Emerging',
#  'Brooklyn, New York.',
#  None,
#  None,
#  'Tampa, Florida. The',
#  None,
#  None,
#  None,
#  None,
#  'LeFrak City, Queens.',
#  'The Bronx, New',
#  None,
#  None,
#  None,
#  'Oakland, California. In',
#  None,
#  'The Bronx, New',
#  'San Jose, California',
#  'New York, New',
#  'his 1980 self-titled',
#  None,
#  'Kansas City, Missouri.[1]',
#  'home. In her',
#  'Memphis, Tennessee. She',
#  None,
#  None,
#  None,
#  'Queensbridge, New York.',
#  None,
#  'New York.[1] He',
#  None,
#  None,
#  None,
#  None,
#  'Los Angeles, California.',
#  None,
#  'Chicago, Illinois. He',
#  'Berkeley, California. Lil',
#  None,
#  None,
#  'Chicago, Illinois.[2] He',
#  None,
#  'Chicago, Illinois. Herb',
#  'Brooklyn, New York',
#  'Chicago, Illinois. He',
#  'Richmond, California, formally',
#  None,
#  'Oak Cliff, Dallas,',
#  None,
#  'Memphis, Tennessee. He',
#  'his debut EP',
#  None,
#  None,
#  'Cloverland, Houston, Texas.',
#  'Houston, Texas and',
#  'home. In her',
#  None,
#  None,
#  None,
#  'Cathedral High School',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Bronx, New',
#  None,
#  'Memphis, Tennessee. He',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Kansas City, Missouri.[3]',
#  None,
#  None,
#  'Memphis, Tennessee, during',
#  'the Ingram MAC-10',
#  'New Orleans, Louisiana.',
#  'Kent, Washington. His',
#  None,
#  None,
#  None,
#  'Detroit, Michigan. Maejor',
#  None,
#  None,
#  'Brooklyn, New York',
#  None,
#  '1993 to 2005',
#  'Indianapolis, Indiana. Battles',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Brownsville, Brooklyn. He',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Wesleyan University in',
#  None,
#  'Compton, California. He',
#  None,
#  None,
#  None,
#  None,
#  'the Moss Side',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'the 1979 film',
#  'St. Louis, Missouri.[2]',
#  None,
#  'New York City.',
#  None,
#  None,
#  None,
#  'the Bronx borough',
#  None,
#  None,
#  None,
#  'the album peaked',
#  None,
#  None,
#  'Willingboro, NJ, signed',
#  None,
#  None,
#  None,
#  'the Poetic Justice',
#  None,
#  'San Diego, California.',
#  '1995 to 1999.',
#  None,
#  None,
#  None,
#  'Brooklyn, New York',
#  None,
#  None,
#  'Southern California, owner',
#  'Boston, Massachusetts. Often',
#  'the Crown Heights',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'New Orleans, Louisiana.',
#  None,
#  None,
#  None,
#  'T.V.", "Nothin\'", "Oye',
#  '1804 until 1814,',
#  None,
#  'other natural phenomena.',
#  None,
#  None,
#  'St. Louis, Missouri.',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Los Angeles, California.',
#  None,
#  'Brooklyn, New York.',
#  'Seattle.[1] He is',
#  'Virginia Beach, Virginia.',
#  None,
#  'Washington, D.C. who',
#  None,
#  'Norfolk, Virginia.[1] Nottz',
#  None,
#  None,
#  'Oakland, California formed',
#  'Fort Wayne, Indiana.',
#  None,
#  'Washington, DC.[3] He',
#  None,
#  'Atlanta, Georgia.[1] He',
#  None,
#  None,
#  'Staten Island, New',
#  'Bariga, Lagos State.[1]',
#  None,
#  None,
#  None,
#  None,
#  'Chicago, Illinois, he',
#  None,
#  None,
#  None,
#  'Houston, Texas.[1] He',
#  'the Narragansett tribe.',
#  None,
#  None,
#  'Houston, Texas. He',
#  None,
#  'Atlanta, Georgia who',
#  'The South Bronx,',
#  'Greenville, North Carolina.[4]',
#  'Queens, New York.',
#  None,
#  'Detroit, Michigan, best',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Fresno, California. He',
#  None,
#  None,
#  None,
#  None,
#  'the Bronx, New',
#  None,
#  None,
#  None,
#  'Amityville, New York.[2]',
#  None,
#  None,
#  None,
#  'London. He is',
#  'Memphis, Tennessee. He',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Lawrenceville, Georgia.[1] The',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Chicago, Illinois.[3][4] Qwazaar',
#  'Chicago, Illinois.[1][2][3][4][5] Qwel',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'the Fillmore District',
#  'Snow Hill, North',
#  None,
#  'Atlanta, Georgia.[1] Rasheeda',
#  None,
#  None,
#  None,
#  'Brampton, Ontario. He',
#  'Long Beach, California.',
#  None,
#  'Chicago, Illinois. He',
#  None,
#  None,
#  None,
#  None,
#  "Lawrence, Massachusetts' underground",
#  'their second album',
#  'Chicago, Illinois, whose',
#  'Mobile, Alabama. He',
#  None,
#  'Atlanta, Georgia; signed',
#  None,
#  None,
#  'Montgomery, Alabama and',
#  None,
#  None,
#  'Gwinnett County, Georgia.',
#  None,
#  None,
#  'The Bronx. He',
#  'Hempstead, Long Island,',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Detroit, Michigan. He',
#  None,
#  'Pittsburg, California best',
#  None,
#  None,
#  None,
#  'Long Beach, California.',
#  'Oakland, California. He',
#  None,
#  'former Egyptian president',
#  'Seattle, Washington. He',
#  'Providence, Rhode Island.',
#  'Fairfield, California. He',
#  None,
#  None,
#  None,
#  'San Francisco, California.',
#  None,
#  None,
#  None,
#  'South Central Los',
#  None,
#  None,
#  None,
#  'New Rochelle, New',
#  None,
#  'Atlanta, Georgia. Scrilla',
#  'West London. He',
#  None,
#  None,
#  None,
#  None,
#  'East Palo Alto,',
#  None,
#  'Albany, New York.',
#  'the Red Hook',
#  None,
#  'Inglewood, California. He',
#  'Oakland.[2] He is',
#  None,
#  None,
#  None,
#  'Atlanta, Georgia. Walker',
#  None,
#  'Japanese ethnicity to',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'No Limit Records',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Brooklyn, New York.',
#  None,
#  'Savannah, Georgia. He',
#  'the 4th Ward',
#  'rapper Mike Jones,',
#  None,
#  'Little Haiti, a',
#  'Harlem, New York',
#  None,
#  None,
#  None,
#  'San Jose, California.[3]',
#  None,
#  None,
#  'Atlanta, Georgia,[3] who',
#  'Brooklyn, New York',
#  'Long Beach, California.',
#  None,
#  None,
#  'the South Park',
#  None,
#  'Miami, Florida. He',
#  'Brooklyn in New',
#  'Hayward, California.[2] He',
#  None,
#  None,
#  None,
#  None,
#  'Massillon, Ohio. He',
#  'Nashville, Tennessee. He',
#  None,
#  'Louisville, Kentucky, USA.',
#  'Boston, Massachusetts. He',
#  None,
#  'Oakland. He is',
#  'St. Louis, Missouri.',
#  'New Haven, Connecticut.[1]',
#  'the slang term',
#  'the Zagreb neighborhood',
#  None,
#  None,
#  None,
#  "Prince George's County,",
#  None,
#  None,
#  None,
#  'her debut album.',
#  'New York City,',
#  None,
#  'Los Angeles, California.[2]',
#  None,
#  'Atlanta, Georgia. Harris',
#  None,
#  'the hip hop',
#  'the short loin',
#  'Sacramento, California and',
#  'Tallahassee, Florida. His',
#  'Houston, Texas.[2] His',
#  'Riverside, California. Following',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'rapper Lil B.[2][3]',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'funk and jazz',
#  'Harlem, New York.',
#  None,
#  None,
#  None,
#  'the Bronx, New',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'the 1983 film',
#  'the mixtape Lost',
#  'the album "All',
#  'Houston, Texas. Apart',
#  'the Queensbridge Housing',
#  'San Jose, California.[1]',
#  None,
#  'New Orleans who',
#  None,
#  'the album, "Say',
#  "Miami's Liberty City.[2]",
#  None,
#  'the label in',
#  'Dallas, Texas,[3] he',
#  None,
#  'the Crown Heights',
#  None,
#  None,
#  'Compton, California. Johnson',
#  'Chicago, Illinois. He',
#  'his eleventh studio',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'East New York,',
#  'Atlanta. Some of',
#  'Aarhus, Denmark, who',
#  None,
#  'Oakland, California. She',
#  'Atlanta, Georgia. His',
#  None,
#  'Chicago, Illinois.[1] Vakill',
#  'Detroit, Michigan, who',
#  None,
#  None,
#  'New York City.',
#  None,
#  None,
#  'Chicago, Illinois.[5] He',
#  'Long Beach, California.',
#  None,
#  None,
#  'New Orleans, Louisiana.',
#  'Germany and Bliss',
#  None,
#  'wear.[1] The garboard',
#  None,
#  'San Francisco, California.',
#  None,
#  'Baton Rouge, Louisiana.',
#  'Buffalo, New York.',
#  None,
#  None,
#  'Houston, Geto Boys.',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
data['location'] = data['artist'].apply(get_location)
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     416             try:
# --> 417                 cnx.do_handshake()
#     418             except OpenSSL.SSL.WantReadError:
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1425         result = _lib.SSL_do_handshake(self._ssl)
# -> 1426         self._raise_ssl_error(self._ssl, result)
#    1427
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1165                     if errno != 0:
# -> 1166                         raise SysCallError(errno, errorcode.get(errno))
#    1167                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (10054, 'WSAECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     322             server_hostname=hostname,
# --> 323             ssl_context=context)
#     324
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     323     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 324         return context.wrap_socket(sock, server_hostname=server_hostname)
#     325
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     423             except OpenSSL.SSL.Error as e:
# --> 424                 raise ssl.SSLError('bad handshake: %r' % e)
#     425             break
#
# SSLError: ("bad handshake: SysCallError(10054, 'WSAECONNRESET')",)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     623             clean_exit = False
# --> 624             raise SSLError(e)
#     625
#
# SSLError: ("bad handshake: SysCallError(10054, 'WSAECONNRESET')",)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-2-7ef6fecdb7e5> in <module>()
# ----> 1 data['location'] = data['artist'].apply(get_location)
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:62658)()
#
# <ipython-input-1-45e425b405ec> in get_location(df)
#      31 import numpy as np
#      32 def get_location(df):
# ---> 33     page1 = requests.get(get_info(df))
#      34     soup1 = BeautifulSoup(page1.content, 'html.parser')
#      35     bio1 = (soup1.select("html body")[0]).find_all('p')[0].get_text()
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Users\danil\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     495         except (_SSLError, _HTTPError) as e:
#     496             if isinstance(e, _SSLError):
# --> 497                 raise SSLError(e, request=request)
#     498             elif isinstance(e, ReadTimeoutError):
#     499                 raise ReadTimeout(e, request=request)
#
# SSLError: ("bad handshake: SysCallError(10054, 'WSAECONNRESET')",)
